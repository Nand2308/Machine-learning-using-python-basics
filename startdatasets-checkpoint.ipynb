# %%
import numpy as np
import pandas as pd

# %%
iris=pd.read_csv(r"C:\Users\Dell\Downloads\iris\iris.data",header=None) #to read the dataset csv-comma seperated values
iris
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.columns=['SL','SW','PL','PW','Flower Type']
iris
# Out:
#       SL   SW   PL   PW     Flower Type
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head(10)
# Out:
#     SL   SW   PL   PW  Flower Type
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa
# 5  5.4  3.9  1.7  0.4  Iris-setosa
# 6  4.6  3.4  1.4  0.3  Iris-setosa
# 7  5.0  3.4  1.5  0.2  Iris-setosa
# 8  4.4  2.9  1.4  0.2  Iris-setosa
# 9  4.9  3.1  1.5  0.1  Iris-setosa

# %%
iris.tail(20)
# Out:
#       SL   SW   PL   PW     Flower Type
# 130  7.4  2.8  6.1  1.9  Iris-virginica
# 131  7.9  3.8  6.4  2.0  Iris-virginica
# 132  6.4  2.8  5.6  2.2  Iris-virginica
# 133  6.3  2.8  5.1  1.5  Iris-virginica
# 134  6.1  2.6  5.6  1.4  Iris-virginica
# 135  7.7  3.0  6.1  2.3  Iris-virginica
# 136  6.3  3.4  5.6  2.4  Iris-virginica
# 137  6.4  3.1  5.5  1.8  Iris-virginica
# 138  6.0  3.0  4.8  1.8  Iris-virginica
# 139  6.9  3.1  5.4  2.1  Iris-virginica
# 140  6.7  3.1  5.6  2.4  Iris-virginica
# 141  6.9  3.1  5.1  2.3  Iris-virginica
# 142  5.8  2.7  5.1  1.9  Iris-virginica
# 143  6.8  3.2  5.9  2.3  Iris-virginica
# 144  6.7  3.3  5.7  2.5  Iris-virginica
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica

# %%
iris.head()
# Out:
#     SL   SW   PL   PW  Flower Type
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
iris.isnull()
# Out:
#         SL     SW     PL     PW  Flower Type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False  False  False  False        False
# 3    False  False  False  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
# 149  False  False  False  False        False
#
# [150 rows x 5 columns]

# %%
iris.isnull().sum()
# Out:
# SL             0
# SW             0
# PL             0
# PW             0
# Flower Type    0
# dtype: int64

# %%
iris['Flower Type'].dtype
# Out:
# dtype('O')

# %%
iris.SL.dtype
# Out:
# dtype('float64')

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SL           150 non-null    float64
#  1   SW           150 non-null    float64
#  2   PL           150 non-null    float64
#  3   PW           150 non-null    float64
#  4   Flower Type  150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.SL.unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
iris.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Flower Type'], dtype='object')

# %%
for i in iris.columns:
    print(i,':','\n',iris[i].unique(),'\n')
# Out:
# SL :
#  [5.1 4.9 4.7 4.6 5.  5.4 4.4 4.8 4.3 5.8 5.7 5.2 5.5 4.5 5.3 7.  6.4 6.9
#  6.5 6.3 6.6 5.9 6.  6.1 5.6 6.7 6.2 6.8 7.1 7.6 7.3 7.2 7.7 7.4 7.9]
#
# SW :
#  [3.5 3.  3.2 3.1 3.6 3.9 3.4 2.9 3.7 4.  4.4 3.8 3.3 4.1 4.2 2.3 2.8 2.4
#  2.7 2.  2.2 2.5 2.6]
#
# PL :
#  [1.4 1.3 1.5 1.7 1.6 1.1 1.2 1.  1.9 4.7 4.5 4.9 4.  4.6 3.3 3.9 3.5 4.2
#  3.6 4.4 4.1 4.8 4.3 5.  3.8 3.7 5.1 3.  6.  5.9 5.6 5.8 6.6 6.3 6.1 5.3
#  5.5 6.7 6.9 5.7 6.4 5.4 5.2]
#
# PW :
#  [0.2 0.4 0.3 0.1 0.5 0.6 1.4 1.5 1.3 1.6 1.  1.1 1.8 1.2 1.7 2.5 1.9 2.1
#  2.2 2.  2.4 2.3]
#
# Flower Type :
#  ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %%
iris.describe(include='all')
# Out:
#                 SL          SW          PL          PW  Flower Type
# count   150.000000  150.000000  150.000000  150.000000          150
# unique         NaN         NaN         NaN         NaN            3
# top            NaN         NaN         NaN         NaN  Iris-setosa
# freq           NaN         NaN         NaN         NaN           50
# mean      5.843333    3.054000    3.758667    1.198667          NaN
# std       0.828066    0.433594    1.764420    0.763161          NaN
# min       4.300000    2.000000    1.000000    0.100000          NaN
# 25%       5.100000    2.800000    1.600000    0.300000          NaN
# 50%       5.800000    3.000000    4.350000    1.300000          NaN
# 75%       6.400000    3.300000    5.100000    1.800000          NaN
# max       7.900000    4.400000    6.900000    2.500000          NaN

# %%
iris['Flower Type'].value_counts()
# Out:
# Flower Type
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# Auto MPG

# %%
#Import packages
import numpy as np
import pandas as pd

# %%
#Reading the dataset
#We can use sep='\s+' or delim_whitespace=True for spacing)
auto=pd.read_csv(r"C:\Users\Dell\Downloads\auto+mpg\auto-mpg.data",header=None,sep='\s+')
auto
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14844\4220352701.py:3: SyntaxWarning: invalid escape sequence '\s'
#   auto=pd.read_csv(r"C:\Users\Dell\Downloads\auto+mpg\auto-mpg.data",header=None,sep='\s+')
#         0  1      2      3       4     5   6  7                          8
# 0    18.0  8  307.0  130.0  3504.0  12.0  70  1  chevrolet chevelle malibu
# 1    15.0  8  350.0  165.0  3693.0  11.5  70  1          buick skylark 320
# 2    18.0  8  318.0  150.0  3436.0  11.0  70  1         plymouth satellite
# 3    16.0  8  304.0  150.0  3433.0  12.0  70  1              amc rebel sst
# 4    17.0  8  302.0  140.0  3449.0  10.5  70  1                ford torino
# ..    ... ..    ...    ...     ...   ...  .. ..                        ...
# 393  27.0  4  140.0  86.00  2790.0  15.6  82  1            ford mustang gl
# ...

# %%
#Rename the columns
auto.columns=['mpg','cylinders','displacement','horse power',' weight','acceleration','model year','origin',' car name']
auto.head()
# Out:
#     mpg  cylinders  displacement horse power   weight  acceleration  \
# 0  18.0          8         307.0       130.0   3504.0          12.0
# 1  15.0          8         350.0       165.0   3693.0          11.5
# 2  18.0          8         318.0       150.0   3436.0          11.0
# 3  16.0          8         304.0       150.0   3433.0          12.0
# 4  17.0          8         302.0       140.0   3449.0          10.5
#
#    model year  origin                   car name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
#to check the missing values
auto.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horse power     0
#  weight         0
# acceleration    0
# model year      0
# origin          0
#  car name       0
# dtype: int64

# %%
#To check the datatypes
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horse power      object
#  weight         float64
# acceleration    float64
# model year        int64
# origin            int64
#  car name        object
# dtype: object

# %%
#To check the unique values
for i in auto.columns:
    print(i,':','\n',auto[i].unique(),'\n')
# Out:
# mpg :
#  [18.  15.  16.  17.  14.  24.  22.  21.  27.  26.  25.  10.  11.   9.
#  28.  19.  12.  13.  23.  30.  31.  35.  20.  29.  32.  33.  17.5 15.5
#  14.5 22.5 24.5 18.5 29.5 26.5 16.5 31.5 36.  25.5 33.5 20.5 30.5 21.5
#  43.1 36.1 32.8 39.4 19.9 19.4 20.2 19.2 25.1 20.6 20.8 18.6 18.1 17.7
#  27.5 27.2 30.9 21.1 23.2 23.8 23.9 20.3 21.6 16.2 19.8 22.3 17.6 18.2
#  16.9 31.9 34.1 35.7 27.4 25.4 34.2 34.5 31.8 37.3 28.4 28.8 26.8 41.5
#  38.1 32.1 37.2 26.4 24.3 19.1 34.3 29.8 31.3 37.  32.2 46.6 27.9 40.8
#  44.3 43.4 36.4 44.6 40.9 33.8 32.7 23.7 23.6 32.4 26.6 25.8 23.5 39.1
#  39.  35.1 32.3 37.7 34.7 34.4 29.9 33.7 32.9 31.6 28.1 30.7 24.2 22.4
#  34.  38.  44. ]
#
# cylinders :
#  [8 4 6 3 5]
#
# displacement :
#  [307.  350.  318.  304.  302.  429.  454.  440.  455.  390.  383.  340.
#  400.  113.  198.  199.  200.   97.  110.  107.  104.  121.  360.  140.
#   98.  232.  225.  250.  351.  258.  122.  116.   79.   88.   71.   72.
# ...

# %%
for i in auto.columns:
    print(i,':',sum(auto[i]=='?'))
# Out:
# mpg : 0
# cylinders : 0
# displacement : 0
# horse power : 6
#  weight : 0
# acceleration : 0
# model year : 0
# origin : 0
#  car name : 0

# %%
d=auto.describe(include='all')
d
# Out:
#                mpg   cylinders  displacement horse power       weight  \
# count   398.000000  398.000000    398.000000         398   398.000000
# unique         NaN         NaN           NaN          94          NaN
# top            NaN         NaN           NaN       150.0          NaN
# freq           NaN         NaN           NaN          22          NaN
# mean     23.514573    5.454774    193.425879         NaN  2970.424623
# std       7.815984    1.701004    104.269838         NaN   846.841774
# min       9.000000    3.000000     68.000000         NaN  1613.000000
# 25%      17.500000    4.000000    104.250000         NaN  2223.750000
# 50%      23.000000    4.000000    148.500000         NaN  2803.500000
# 75%      29.000000    8.000000    262.000000         NaN  3608.000000
# max      46.600000    8.000000    455.000000         NaN  5140.000000
#
#         acceleration  model year      origin    car name
# count     398.000000  398.000000  398.000000         398
# ...

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
auto['horse power'].replace('?',d['horse power'][2],inplace=True)

# %%
for i in  auto.columns:
    print(i,':',sum(auto[i]=='?'))
# Out:
# mpg : 0
# cylinders : 0
# displacement : 0
# horse power : 0
#  weight : 0
# acceleration : 0
# model year : 0
# origin : 0
#  car name : 0

# %%
auto['horse power'] = auto['horse power'].astype(float) #to convert int to float
auto.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horse power     float64
#  weight         float64
# acceleration    float64
# model year        int64
# origin            int64
#  car name        object
# dtype: object
